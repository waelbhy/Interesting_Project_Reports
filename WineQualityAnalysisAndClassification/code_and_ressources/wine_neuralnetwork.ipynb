# %%
from sklearn.model_selection import train_test_split
import keras
from keras.models import Sequential
from keras.layers import Dense 
import numpy as np
import os
import pandas

np.random.seed(3)

print(os.getcwd())

# number of wine classes
classifications = 3

# load dataset
#dataset = np.loadtxt('wine.csv', delimiter=",",skiprows=1)
#print(dataset)

dataset = pandas.read_csv('wine.csv',header=0)#,usecols=['fixed_acidity','volatile_acidity','citric_acid','residual_sugar','chlorides','free_sulfur_dioxide','total_sulfur_dioxide','density','pH','sulphates','alcohol','quality_bis'])
print(dataset)


# split dataset into sets for testing and training
X = dataset.iloc[:,1:12]
print(X)
Y = dataset.iloc[:,12:13]
print(Y)
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.66, random_state=5)

# convert output values to one-hot
y_train = keras.utils.to_categorical(y_train-1, num_classes=classifications)
y_test = keras.utils.to_categorical(y_test-1, num_classes=classifications)


# creating model
model = Sequential()
model.add(Dense(10, input_dim=11, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(6, activation='relu'))
model.add(Dense(6, activation='relu'))
model.add(Dense(4, activation='relu'))
#model.add(Dense(4, activation='relu'))
#model.add(Dense(2, activation='relu'))
model.add(Dense(2, activation='relu'))
model.add(Dense(classifications, activation='softmax'))

# compile and fit model
model.compile(loss="categorical_crossentropy", optimizer="adam", metrics=['accuracy'])
model.fit(x_train, y_train, batch_size=15, epochs=2500, validation_data=(x_test, y_test))
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
# 1071/1071 [==============================] - 0s 267us/step - loss: 0.6116 - accuracy: 0.8207 - val_loss: 0.6056 - val_accuracy: 0.8182
# Epoch 2/2500
# 1071/1071 [==============================] - 0s 110us/step - loss: 0.5557 - accuracy: 0.8282 - val_loss: 0.5953 - val_accuracy: 0.8182
# Epoch 3/2500
# 1071/1071 [==============================] - 0s 107us/step - loss: 0.5545 - accuracy: 0.8282 - val_loss: 0.5848 - val_accuracy: 0.8182
# Epoch 4/2500
# 1071/1071 [==============================] - 0s 111us/step - loss: 0.5505 - accuracy: 0.8282 - val_loss: 0.5800 - val_accuracy: 0.8182
# Epoch 5/2500
# 1071/1071 [==============================] - 0s 110us/step - loss: 0.5488 - accuracy: 0.8282 - val_loss: 0.5784 - val_accuracy: 0.8182
# Epoch 6/2500
# 1071/1071 [==============================] - 0s 110us/step - loss: 0.5470 - accuracy: 0.8282 - val_loss: 0.5777 - val_accuracy: 0.8182
# Epoch 7/2500
# ...

# %%
for layer in model.layers:
    weights = layer.get_weights()
    #print(weights)

#quality = 3
test2 = np.array([[7.4,	1.185,	0.00,	4.25,	0.097,	5,	14,	0.99660,	3.63,	0.54,	10.70]])
test4 = np.array([[5.7,	1.130,	0.09,	1.50,	0.172,	7,	19,	0.99400,	3.50,	0.48,	9.80]])
test5 = np.array([[8.8,	0.610,	0.30,	2.80,	0.088,	17,	46,	0.99760,	3.26,	0.51,	9.30]])
test6 = np.array([[7.1,	0.875,	0.05,	5.70,	0.082,	3,	14,	0.99808,	3.40,	0.52,	10.20]])
test7 = np.array([[6.7,	0.760,	0.02,	1.80,	0.078,	6,	12,	0.99600,	3.55,	0.63,	9.95]])

#quality = 4
test11 = np.array([[7.1,	0.470,	0.00,	2.20,	0.067,	7,	14,	0.99517,	3.40,	0.58,	10.90]])
test12 = np.array([[8.1,	0.730,	0.00,	2.50,	0.081,	12,	24,	0.99798,	3.38,	0.46,	9.60]])
test13 = np.array([[8.2,	0.780,	0.00,	2.20,	0.089,13,	26,	0.99780,	3.37,	0.46, 	9.60]])

#quatity = 5
test = np.array([[7.4 , 0.7 , 0 , 1.9 , 0.076 , 11 , 34 , 0.9978 , 3.51 , 0.56 , 9.4]])
test19 = np.array([[6.6,	0.705,	0.07,	1.60,	0.076,	6,	15,	0.99620,	3.44,	0.58,	10.70]])
test20 = np.array([[7.7,	0.670,	0.23,	2.10,	0.088,	17,	96,	0.99620,	3.32,	0.48,	9.50]])

#quatity = 6
test3 =np.array([[7.8,	0.600,	0.14,	2.40,	0.086,	3.0,	15,	0.99750,	3.42,	0.60,	10.8]])
test21 = np.array([[8.5,	0.585,	0.18,	2.10,	0.078,	5.0,	30,	0.99670,	3.20,	0.48,	9.8]])
test22 = np.array([[12.7,	0.590,	0.45,	2.30,	0.082,	11.0,	22,	1.00000,	3.00,	0.70,	9.3]])
test23 = np.array([[13.2,	0.460,	0.52,	2.20,	0.071,	12.0,	35,	1.00060, 3.10,	0.56,	9.0]])

#quality = 7
test14 = np.array([[7.2,	0.370,	0.32,	2.00,	0.062,	15.0,	28,	0.99470,	3.23,	0.73,	11.30000]])
test15 = np.array([[7.3,	0.340,	0.33,	2.50,	0.064,	21.0,	37,	0.99520,	3.35,	0.77,	12.10000]])
test16 = np.array([[8.5,	0.320,	0.42,	2.30,	0.075,	12.0,	19,	0.99434,	3.14,	0.71,	11.80000]])
test17 = np.array([[5.4,	0.420,	0.27,	2.00,	0.092,	23.0,	55,	0.99471,	3.78,	0.64,	12.30000]])
test18 = np.array([[11.6,	0.410,	0.54,	1.50,	0.095,	22.0,	41,	0.99735,	3.02,	0.76,	9.90000	]])

#quality = 8
test1 = np.array([[7.9,	0.35,	0.46,	3.6,	0.078,	15,	37,	0.99730,	3.35,	0.86,	12.8]])
test8 = np.array([[5.0,	0.420,	0.24,	2.00,	0.060,	19.0,	50,	0.99170,	3.72,	0.74,	14.00000]])
test9 = np.array([[9.1,	0.400,	0.50,	1.80,	0.071,	7.0,	16,	0.99462,	3.21,	0.69,	12.50000]])
test10 = np.array([[8.6,	0.420,	0.39,	1.80,	0.068,	6.0,	12,	0.99516,	3.35,	0.69,	11.70000]])



print("class=3, expected=1, Predicted=%s" % (model.predict_classes(test2)+1 ))
print("class=3, expected=1, Predicted=%s" % (model.predict_classes(test4)+1 ))
print("class=3, expected=1, Predicted=%s" % (model.predict_classes(test5)+1 ))
print("class=3, expected=1, Predicted=%s" % (model.predict_classes(test6)+1 ))
print("class=3, expected=1, Predicted=%s \n" % (model.predict_classes(test7)+1 ))

print("class=4, expected=1, Predicted=%s" % (model.predict_classes(test11)+1 ))
print("class=4, expected=1, Predicted=%s" % (model.predict_classes(test12)+1 ))
print("class=4, expected=1, Predicted=%s \n" % (model.predict_classes(test13)+1 ))

print("class=5, expected=2, Predicted=%s" % (model.predict_classes(test)+1 ))
print("class=5, expected=2, Predicted=%s" % (model.predict_classes(test19)+1 ))
print("class=5, expected=2, Predicted=%s \n" % (model.predict_classes(test20)+1 ))

print("class=6, expected=2, Predicted=%s" % (model.predict_classes(test3)+1 ))
print("class=6, expected=2, Predicted=%s" % (model.predict_classes(test21)+1 ))
print("class=6, expected=2, Predicted=%s" % (model.predict_classes(test22)+1 ))
print("class=6, expected=2, Predicted=%s \n" % (model.predict_classes(test23)+1 ))

print("class=7, expected=3, Predicted=%s" % (model.predict_classes(test14)+1 ))
print("class=7, expected=3, Predicted=%s" % (model.predict_classes(test15)+1 ))
print("class=7, expected=3, Predicted=%s" % (model.predict_classes(test16)+1 ))
print("class=7, expected=3, Predicted=%s" % (model.predict_classes(test17)+1 ))
print("class=7, expected=3, Predicted=%s \n" % (model.predict_classes(test18)+1 ))

print("class=8, expected=3, Predicted=%s" % (model.predict_classes(test1)+1 ))
print("class=8, expected=3, Predicted=%s" % (model.predict_classes(test8)+1 ))
print("class=8, expected=3, Predicted=%s" % (model.predict_classes(test9)+1 ))
print("class=8, expected=3, Predicted=%s" % (model.predict_classes(test10)+1 ))




#print(model.predict_proba(test2))
# Out:
# class=3, expected=1, Predicted=[2]
# class=3, expected=1, Predicted=[2]
# class=3, expected=1, Predicted=[2]
# class=3, expected=1, Predicted=[2]
# class=3, expected=1, Predicted=[2]
#
# class=4, expected=1, Predicted=[2]
# class=4, expected=1, Predicted=[2]
# class=4, expected=1, Predicted=[2]
#
# class=5, expected=2, Predicted=[2]
# class=6, expected=2, Predicted=[2]
#
# class=7, expected=3, Predicted=[2]
# class=7, expected=3, Predicted=[3]
# class=7, expected=3, Predicted=[3]
# class=7, expected=3, Predicted=[2]
# class=7, expected=3, Predicted=[2]
#
# class=8, expected=3, Predicted=[3]
# class=8, expected=3, Predicted=[3]
# class=8, expected=3, Predicted=[3]
# class=8, expected=3, Predicted=[3]

# %%
import matplotlib.pyplot as plt

def draw_neural_net(ax, left, right, bottom, top, layer_sizes):
    '''
    Draw a neural network cartoon using matplotilb.
    
    :usage:
        >>> fig = plt.figure(figsize=(12, 12))
        >>> draw_neural_net(fig.gca(), .1, .9, .1, .9, [4, 7, 2])
    
    :parameters:
        - ax : matplotlib.axes.AxesSubplot
            The axes on which to plot the cartoon (get e.g. by plt.gca())
        - left : float
            The center of the leftmost node(s) will be placed here
        - right : float
            The center of the rightmost node(s) will be placed here
        - bottom : float
            The center of the bottommost node(s) will be placed here
        - top : float
            The center of the topmost node(s) will be placed here
        - layer_sizes : list of int
            List of layer sizes, including input and output dimensionality
    '''
    n_layers = len(layer_sizes)
    v_spacing = (top - bottom)/float(max(layer_sizes))
    h_spacing = (right - left)/float(len(layer_sizes) - 1)
    # Nodes
    for n, layer_size in enumerate(layer_sizes):
        layer_top = v_spacing*(layer_size - 1)/2. + (top + bottom)/2.
        for m in range(layer_size):
            circle = plt.Circle((n*h_spacing + left, layer_top - m*v_spacing), v_spacing/4.,
                                color='w', ec='k', zorder=4)
            ax.add_artist(circle)
    # Edges
    for n, (layer_size_a, layer_size_b) in enumerate(zip(layer_sizes[:-1], layer_sizes[1:])):
        layer_top_a = v_spacing*(layer_size_a - 1)/2. + (top + bottom)/2.
        layer_top_b = v_spacing*(layer_size_b - 1)/2. + (top + bottom)/2.
        for m in range(layer_size_a):
            for o in range(layer_size_b):
                line = plt.Line2D([n*h_spacing + left, (n + 1)*h_spacing + left],
                                  [layer_top_a - m*v_spacing, layer_top_b - o*v_spacing], c='k')
                ax.add_artist(line)

# %%
fig = plt.figure(figsize=(12, 12))
draw_neural_net(fig.gca(), .1, .9, .1, .9, [10, 8, 6,6,4,2])
